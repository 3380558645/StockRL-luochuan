# %%
from stable_baselines3.common.save_util import load_from_zip_file
model_dir='./learn/train_file/ppo.model'
# Out:
# c:\users\w\appdata\local\programs\python\python39\lib\site-packages\setuptools\distutils_patch.py:25: UserWarning: Distutils was imported before Setuptools. This usage is discouraged and may exhibit undesirable behaviors or errors. Please use Setuptools' objects directly or at least import Setuptools first.
#   warnings.warn(

# %%
data,params,_=load_from_zip_file(model_dir)
params
# Out:
# {'policy': OrderedDict([('log_std',
#                tensor([0.0492, 0.0187, 0.0602, 0.0418, 0.0355, 0.0519, 0.0693, 0.0348, 0.0476,
#                        0.0280, 0.0420, 0.0334, 0.0461, 0.0548, 0.0907, 0.0518, 0.0481, 0.0336,
#                        0.0634, 0.0447, 0.0205, 0.0429, 0.0479, 0.0600, 0.0271, 0.0501, 0.0926,
#                        0.0680, 0.0366, 0.0536, 0.0408, 0.0290, 0.0508, 0.0487, 0.0584, 0.0097,
#                        0.0488, 0.0463, 0.0338, 0.0358, 0.0355, 0.0648, 0.0419, 0.0245, 0.0208,
#                        0.0179, 0.0315, 0.0559, 0.0676, 0.0266])),
#               ('mlp_extractor.policy_net.0.weight',
#                tensor([[ 0.1358, -0.0324, -0.0305,  ...,  0.0833,  0.0513, -0.0617],
#                        [-0.0345,  0.0334, -0.0499,  ...,  0.0335,  0.0520,  0.0662],
#                        [-0.0095,  0.0147, -0.0346,  ..., -0.0243, -0.0328,  0.0327],
#                        ...,
# ...

# %%
data
# Out:
# {'policy_class': stable_baselines3.common.policies.ActorCriticPolicy,
#  'verbose': 0,
#  'policy_kwargs': {},
#  'observation_space': Box([-inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf
#   -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf
#   -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf
#   -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf
#   -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf
#   -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf
#   -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf
#   -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf
#   -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf
#   -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf
#   -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf -inf
# ...
